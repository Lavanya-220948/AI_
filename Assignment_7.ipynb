# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavanya-220948/AI_/blob/main/Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Define a class Car with attributes and a method to display details.
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_details(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Year:", self.year)


car1 = Car("Toyota", "Fortuner", 2023)
car1.display_details()
# Out:
# Brand: Toyota
# Model: Fortuner
# Year: 2023

# %%
#Explain the purpose of the __init__ method.
class Student:
    def __init__(self, name):
        self.name = name

s = Student("Rahul")
print(s.name)
# Out:
# Rahul

# %% [markdown]
# __init__ is a constructor in Python.
# It is automatically called when an object is created.
# It initializes the object's attributes.

# %%
#Create a subclass ElectricCar that inherits from Car.
class Car:
    def __init__(self, brand):
        self.brand = brand

    def show(self):
        print("Brand:", self.brand)


class ElectricCar(Car):
    def __init__(self, brand, battery):
        super().__init__(brand)
        self.battery = battery

    def display(self):
        print("Brand:", self.brand)
        print("Battery:", self.battery)


e = ElectricCar("Tesla", "75 kWh")
e.display()
# Out:
# Brand: Tesla
# Battery: 75 kWh

# %%
#Demonstrate Method Overriding in inheritance.
class Animal:
    def sound(self):
        print("Animal makes a sound")


class Dog(Animal):
    def sound(self):
        print("Dog barks")


d = Dog()
d.sound()
# Out:
# Dog barks

# %%
#Explain Encapsulation by creating private attributes using __.
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def show_balance(self):
        print("Balance:", self.__balance)


account = BankAccount(5000)
account.show_balance()
# Out:
# Balance: 5000

# %%
#Use @property to create getter and setter methods
class Student:
    def __init__(self):
        self.__marks = 0

    @property
    def marks(self):
        return self.__marks

    @marks.setter
    def marks(self, value):
        self.__marks = value


s = Student()
s.marks = 95
print(s.marks)
# Out:
# 95

# %%
#What is Multiple Inheritance? Provide a small code structure.
class Father:
    def father_method(self):
        print("Father Method")


class Mother:
    def mother_method(self):
        print("Mother Method")


class Child(Father, Mother):
    pass


c = Child()
c.father_method()
c.mother_method()
# Out:
# Father Method
# Mother Method

# %% [markdown]
# Multiple inheritance means a class inherits properties and methods from more than one parent class.

# %%
#Create a class method using the @classmethod decorator.
class Student:
    school = "ABC School"

    @classmethod
    def display_school(cls):
        print("School Name:", cls.school)


Student.display_school()
# Out:
# School Name: ABC School

# %%
#Explain the difference between a class method and a static method.
class Demo:

    @classmethod
    def class_method(cls):
        print("This is a class method")

    @staticmethod
    def static_method():
        print("This is a static method")


Demo.class_method()
Demo.static_method()
# Out:
# This is a class method
# This is a static method

# %%
#Write a try-except-finally block to handle a ZeroDivisionError.
try:
    a = int(input("Enter numerator: "))
    b = int(input("Enter denominator: "))
    result = a / b
    print("Result:", result)

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")

finally:
    print("Program execution completed.")
# Out:
# Enter numerator: 23
# Enter denominator: 56
# Result: 0.4107142857142857
# Program execution completed.
